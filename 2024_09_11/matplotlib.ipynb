# %% [markdown]
# # Matplotlib
#
# Matplotlib est une librairie utilisée pour tracer de graphique en Python
#
# ## Utiliser une librairie

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([0, 1, 2, 3], [2.2, 4.5, 3, 5], ':ro')
plt.xlabel('Abscisse')
plt.ylabel('Ordonnée')
plt.show()

# %%
from math import sin
abscisse = []
ordonnee = []
for i in range(0, 100):
    x = i/10
    abscisse.append(x)
    ordonnee.append(sin(x))
    
plt.plot(abscisse, ordonnee)
